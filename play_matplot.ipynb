# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4])#x축 자동생성성
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])# plot([x],[y])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')#'r = red o = 점
plt.axis([0, 6, 0, 20]) #그래프 값 x : 0~6 y:0~20
plt.show()

# %%
import numpy as np

t = np.arange(0., 5., 0.2)

plt.plot(t,t,'r--', t,t**2,'bs',t,t**3, 'g^')
plt.show()

# %%
plt.plot([2, 3, 5, 10])
plt.show()
